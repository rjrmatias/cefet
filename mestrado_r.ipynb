# %% [markdown]
# # Introdução
# ### Ribamar Matias

# %%
df <- readRDS('/resources/data/teste/ccbh4851_discreto1.rds')
df
# Out:
#      Description
# 1    DNAA_PSEAEChromosomal replication initiator protein DnaA OS=Pseudomonas aeruginosa (strain ATCC 15692 / DSM 22644 / CIP 104116 / JCM 14847 / LMG 12228 / 1C / PRS 101 / PAO1) OX=208964 GN=dnaA PE=3 SV=1
# 2    DPO3B_PSEAEBeta sliding clamp OS=Pseudomonas aeruginosa (strain ATCC 15692 / DSM 22644 / CIP 104116 / JCM 14847 / LMG 12228 / 1C / PRS 101 / PAO1) OX=208964 GN=dnaN PE=1 SV=1
# 3    RECF_PSEAEDNA replication and repair protein RecF OS=Pseudomonas aeruginosa (strain ATCC 15692 / DSM 22644 / CIP 104116 / JCM 14847 / LMG 12228 / 1C / PRS 101 / PAO1) OX=208964 GN=recF PE=3 SV=1
# 4    GYRB_PSEAEDNA gyrase subunit B OS=Pseudomonas aeruginosa (strain ATCC 15692 / DSM 22644 / CIP 104116 / JCM 14847 / LMG 12228 / 1C / PRS 101 / PAO1) OX=208964 GN=gyrB PE=3 SV=1
# 5    INSN_SHIDYTransposase InsN for insertion sequence element IS911 OS=Shigella dysenteriae OX=622 GN=insN PE=3 SV=1
# ...
